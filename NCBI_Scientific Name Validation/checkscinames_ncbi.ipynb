# %%
import pandas as pd
from ete3 import NCBITaxa
from tqdm import tqdm

# %%
def is_valid_scientific_name(name, ncbi):
    try:
        taxid = ncbi.get_name_translator([name]).get(name)
        return taxid is not None
    except Exception as e:
        print(f"Error: {e}")
        return False

def validate_scientific_names(file_path, column_name):
    df = pd.read_excel(file_path)
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the Excel file.")

    ncbi = NCBITaxa()
    valid_names = []
    invalid_names = []

    for name in tqdm(df[column_name], desc="Validating names", unit="name"):
        is_valid = is_valid_scientific_name(name, ncbi)
        if is_valid:
            valid_names.append(name)
        else:
            invalid_names.append(name)

    return valid_names, invalid_names

file_path = "C:/Users/USER/FPIDatabase_RA_100.xlsx"
column_name = "ScientificName"

try:
    valid_names, invalid_names = validate_scientific_names(file_path, column_name)

    print("Valid Scientific Names:")
    print(valid_names)

    print("\nInvalid Scientific Names:")
    print(invalid_names)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Validating names: 100%|██████████| 99/99 [00:00<00:00, 1697.63name/s]
# Valid Scientific Names:
# ['Abelmoschus ficulneus', 'Abelmoschus manihot', 'Abelmoschus moschatus', 'Abelmoschus moschatus subsp. tuberosus', 'Abies firma', 'Abies grandis', 'Abobra tenuifolia', 'Abronia fragrans', 'Abronia latifolia', 'Abrus precatorius', 'Bakeridesia esculenta', 'Abutilon indicum', 'Abutilon otocarpum', 'Abutilon theophrasti', 'Acacia acradenia', 'Acacia acuminata', 'Acacia adoxa', 'Acacia adsurgens', 'Faidherbia albida', 'Acacia ammobia', 'Acacia ampliceps', 'Acacia anaticeps', 'Acacia ancistrocarpa', 'Acacia aneura', 'Senegalia ataxacantha', 'Acacia auriculiformis', 'Acacia beauverdiana', 'Acacia bivenosa', 'Acacia brachystachya', 'Acacia calcicola', 'Acacia cambagei', 'Acacia citrinoviridis', 'Acacia cochliacantha', 'Acacia colei', 'Acacia complanata', 'Acacia concinna', 'Acacia concurrens', 'Acacia coriacea', 'Acacia cowleana', 'Acacia craspedocarpa', 'Acacia crassicarpa', 'Acacia decora', 'Acacia decurrens', 'Acacia dictyophleba', 'Acacia difficilis', 'Acacia drepanolobium', 'Acacia dunnii', 'Vachellia erioloba', 'Acacia eriopoda', 'Senegalia erubescens', 'Acacia estrophiolata', 'Acacia farnesiana', 'Acacia georginae', 'Vachellia gerrardii', 'Acacia giraffae', 'Acacia glaucocaesia', 'Acacia gonocarpa', 'Acacia grasbyi', 'Acacia greggii', 'Vachellia haematoxylon', 'Vachellia hebeclada', 'Acacia hemignosta', 'Acacia hilliana', 'Acacia holosericea', 'Acacia inaequilatera', 'Acacia pennata subsp. insuavis', 'Vachellia jacquemontii', 'Acacia jennerae', 'Vachellia karroo', 'Acacia kempeana', 'Acacia latescens', 'Acacia leiophylla', 'Acacia leptocarpa', 'Vachellia leucophloea', 'Acacia ligulata', 'Acacia linophylla', 'Acacia longifolia', 'Acacia lysiphloia', 'Acacia maconochieana', 'Acacia macrostachya', 'Acacia maitlandii', 'Acacia mangium', 'Acacia melanoxylon', 'Acacia mellifera subsp. detinens', 'Acacia microbotrya', 'Acacia minyura']
#
# Invalid Scientific Names:
# ['Abroma augusta', 'Abuta platyphylla', 'Abutilon mauritianum var. cabrae', 'Abutilon leucopetalum', 'Acacia bidwillii', 'Acacia valida', 'Acacia cutherbertsonii', 'Acacia edgeworthii', 'Senegalia fleckii', 'Acacia flexicaulis', 'Acacia laccata', 'Acacia macdonelliensis', 'Acacia macrothyrsa']

# %%
import pandas as pd
from ete3 import NCBITaxa
from tqdm import tqdm

# %%
def is_valid_scientific_name(name, ncbi):
    try:
        taxid = ncbi.get_name_translator([name]).get(name)
        return taxid is not None
    except Exception as e:
        print(f"Error: {e}")
        return False

def validate_scientific_names(file_path, column_name):
    df = pd.read_excel(file_path)
    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the Excel file.")

    ncbi = NCBITaxa()
    valid_names = []
    invalid_names = []

    for name in tqdm(df[column_name], desc="Validating names", unit="name"):
        is_valid = is_valid_scientific_name(name, ncbi)
        if is_valid:
            valid_names.append(name)
        else:
            invalid_names.append(name)

    validation_results = pd.DataFrame({
        "ScientificName_Cor": valid_names + invalid_names,
        "Validity": [True] * len(valid_names) + [False] * len(invalid_names)
    })

    output_file_path = "validation_results_ete3_Corr.xlsx"
    validation_results.to_excel(output_file_path, index=False)

    return valid_names, invalid_names

file_path = "C:/Users/USER/Downloads/validation_results_ete3_1.xlsx"
column_name = "ScientificName_Cor"

try:
    valid_names, invalid_names = validate_scientific_names(file_path, column_name)

    print("Valid Scientific Names:")
    print(valid_names)

    print("\nInvalid Scientific Names:")
    print(invalid_names)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Validating names: 100%|██████████| 33511/33511 [00:06<00:00, 4817.40name/s]
# Valid Scientific Names:
# ['Abelmoschus ficulneus', 'Abelmoschus manihot', 'Abelmoschus moschatus', 'Abelmoschus moschatus subsp. tuberosus', 'Abies firma', 'Abies grandis', 'Abobra tenuifolia', 'Abronia fragrans', 'Abronia latifolia', 'Abrus precatorius', 'Bakeridesia esculenta', 'Abutilon indicum', 'Abutilon otocarpum', 'Abutilon theophrasti', 'Acacia acradenia', 'Acacia acuminata', 'Acacia adoxa', 'Acacia adsurgens', 'Faidherbia albida', 'Acacia ammobia', 'Acacia ampliceps', 'Acacia anaticeps', 'Acacia ancistrocarpa', 'Acacia aneura', 'Senegalia ataxacantha', 'Acacia auriculiformis', 'Acacia beauverdiana', 'Acacia bivenosa', 'Acacia brachystachya', 'Acacia calcicola', 'Acacia cambagei', 'Acacia citrinoviridis', 'Acacia cochliacantha', 'Acacia colei', 'Acacia complanata', 'Acacia concinna', 'Acacia concurrens', 'Acacia coriacea', 'Acacia cowleana', 'Acacia craspedocarpa', 'Acacia crassicarpa', 'Acacia decora', 'Acacia decurrens', 'Acacia dictyophleba', 'Acacia difficilis', 'Acacia drepanolobium', 'Acacia dunnii', 'Vachellia erioloba', 'Acacia eriopoda', 'Senegalia erubescens', 'Acacia estrophiolata', 'Acacia farnesiana', 'Acacia georginae', 'Vachellia gerrardii', 'Acacia giraffae', 'Acacia glaucocaesia', 'Acacia gonocarpa', 'Acacia grasbyi', 'Acacia greggii', 'Vachellia haematoxylon', 'Vachellia hebeclada', 'Acacia hemignosta', 'Acacia hilliana', 'Acacia holosericea', 'Acacia inaequilatera', 'Acacia pennata subsp. insuavis', 'Vachellia jacquemontii', 'Acacia jennerae', 'Vachellia karroo', 'Acacia kempeana', 'Acacia latescens', 'Acacia leiophylla', 'Acacia leptocarpa', 'Vachellia leucophloea', 'Acacia ligulata', 'Acacia linophylla', 'Acacia longifolia', 'Acacia lysiphloia', 'Acacia maconochieana', 'Acacia macrostachya', 'Acacia maitlandii', 'Acacia mangium', 'Acacia melanoxylon', 'Acacia mellifera subsp. detinens', 'Acacia microbotrya', 'Acacia minyura', 'Acacia monticola', 'Acacia murrayana', 'Vachellia nilotica', 'Acacia nilotica subsp. indica', 'Vachellia nilotica subsp. subalata', 'Acacia nilotica subsp. tomentosa', 'Acacia notabilis', 'Vachellia oerfota', 'Acacia olgana', 'Acacia omalophylla', 'Acacia oshanesii', 'Acacia pachyacra', 'Acacia pachycarpa', 'Acacia pennata', 'Acacia pennatula', 'Acacia podalyriifolia', 'Acacia pruinocarpa', 'Acacia pycnantha', 'Acacia pyrifolia', 'Acacia ramulosa', 'Vachellia reficiens', 'Acacia retinodes', 'Acacia retivenea', 'Acacia rivalis', 'Acacia rostellifera', 'Acacia sabulosa', 'Acacia salicina', 'Acacia saligna', 'Acacia sclerosperma', 'Senegalia senegal', 'Vachellia seyal', 'Vachellia sieberiana', 'Acacia longifolia subsp. sophorae', 'Acacia spectabilis', 'Acacia stenophylla', 'Acacia stipuligera', 'Acacia stricta', 'Acacia suaveolens', 'Acacia synchronicia', 'Acacia tenuissima', 'Acacia tetragonophylla', 'Vachellia tortilis', 'Vachellia tortilis subsp. spirocarpa', 'Vachellia tortilis subsp. heteracantha', 'Acacia torulosa', 'Acacia translucens', 'Acacia tumida', 'Acacia tysonii', 'Acacia umbellata', 'Acacia victoriae', 'Acacia wanyu', 'Acacia xiphophylla', 'Albizia boivinii', 'Acaena anserinifolia', 'Acalypha ciliata', 'Acalypha glabrata', 'Acalypha hispida', 'Acalypha indica', 'Acalypha nemorum', 'Acalypha siamensis', 'Acalypha volkensii', 'Acalypha wilkesiana', 'Amaranthus acanthochiton', 'Acanthophoenix rubra', 'Acanthophora spicifera', 'Acanthosicyos horridus', 'Acanthosicyos naudinianus', 'Acanthus montanus', 'Acca sellowiana', 'Acer campestre', 'Acer glabrum', 'Acer macrophyllum', 'Acer negundo', 'Acer palmatum', 'Acer rubrum', 'Acer saccharinum', 'Acer saccharum', 'Acer saccharum subsp. grandidentatum', 'Acer saccharum subsp. nigrum', 'Acer tataricum', 'Acer truncatum', 'Aceratium doggrellii', 'Aceratium ferrugineum', 'Aceratium megalospermum', 'Aceratium oppositifolium', 'Aceratium sericoleopsis', 'Rumex acetosella subsp. angiocarpus', 'Achillea ageratum', 'Achillea millefolium', 'Achillea ptarmica', 'Achillea sibirica', 'Achyrachaena mollis', 'Achyranthes aspera', 'Achyranthes bidentata', 'Cyrtos ...
#
# Invalid Scientific Names:
# ['Abroma augusta', 'Abuta platyphylla', 'Abutilon mauritianum var. cabrae', 'Abutilon leucopetalum', 'Acacia bidwillii', 'Acacia valida', 'Acacia cutherbertsonii', 'Acacia edgeworthii', 'Senegalia fleckii', 'Acacia flexicaulis', 'Acacia laccata', 'Acacia macdonelliensis', 'Acacia macrothyrsa', 'Acacia nilotica subsp. adansonii', 'Acacia oligophleba', 'Acacia oswaldtii', 'Acacia pallida', 'Acacia palustris', 'Acacia polyacantha subsp. campylacantha', 'Acalypha boehmeroides', 'Acalypha nemora', 'Acer interius', 'Acer cappadocicum var. indicum', 'Acer pseudoplanatus', 'Etlingera foetens', 'Achyranthes faureri', 'Aconitum koreanum', 'Aconitum mokchangense', 'Aconitum multifidum', 'Acronychia aberrans', 'Acronychia acrynychioides', 'Acronychia bauerlenii', 'Acrotriche prostrata', 'Actinella odorata', 'Actinidia arguta var. cordifolia', 'Actinidia arguta var. rufa', 'Actinidia arguta x kolomikta', 'Actinidia arguta x melanandra', 'Actinidia callosa var. callosa', 'Actinidia asymmetrica', 'Actinidia callosa var. indochinensis', 'Actinidia callosa var. pubescens', 'Actinidia coriacea', 'Actinidia giraldii', 'Actinidia glabra', 'Actinidia holotricha', 'Actinidia kiusiana', 'Actinidia kolomikta var. gagnepainii', 'Actinidia kwangsiensis', 'Actinidia maloides', 'Actinidia petelotii', 'Actinidia polygama var. lecomtei', 'Actinidia purpurea', 'Actinidia trichogyna', 'Actinidia x fairchildii', 'Adenanthera abrosperma', 'Adenophora denticulata', 'Adenophora latifolia', 'Adiantum capillis-veneris', 'Adinandra luzonica', 'Aegopodium podograria', 'Aeollanthus frutescens', 'Aeollanthus suaveolens', 'Aeollanthus pubescens', 'Aerva tomentosa', 'Aframomum elliotii', 'Aframomum giganteum', 'Aframomum longiscapum', 'Aframomum sulcatum', 'Afzelia bijuga', 'Amphineuron marginatum', 'Agapanthus praecox var. minimus', 'Agaricus spp', 'Agastache neomexicana', 'Agathis sp.', 'Agave americana var. expansa', 'Agave vivipara', 'Agave cantala', 'Agave cerulata subsp. dentiens', 'Agave utahensis var. eborispina', 'Agave vera-cruz', 'Aglaia everettii', 'Aglaia sp.', 'Agoseris villosa', 'Aira caespitosa', 'Alafia lucida', 'Albizia sp.', 'Alchemilla xanthoclora', 'Alectryon macrococcum', 'Alepidea spp.', 'Aleurites cordatus', 'Allagoptera maritimum', 'Allanblackia stuhlmannii', 'Allanblackia ulugurensis', 'Allium ampeloprasum var. babbingtonii', 'Allium cepa var. proliferum', 'Allium synnotii', 'Allium longifolium', 'Allium ampeloprasum var. kurrat', 'Allium nigritanum', 'Allium ampeloprasum var. porrum', 'Allium rubrum', 'Allium ruhmerianum', 'Allium sativum var. ophioscorodon', 'Allium stracheyii', 'Allophylus macrostachys', 'Alocasia lancifolia', 'Aloe cooperi', 'Platymitra arborea', 'Alsodeiopsis staudtii ', 'Alstroemeria haemantha', 'Alstroemeria spectabilis', 'Alternanthera versicolor', 'Amanita spp', 'Amaranthus angustifolius', 'Amaranthus bidentata', 'Amaranthus campestris', 'Amaranthus diacanthus', 'Amaranthus grandiflorus', 'Amaranthus pallidiflorus', 'Amaranthus polygamus', 'Amaranthus hybridus subsp. quitensis', 'Amelanchier sanguinea var. alnifolia', 'Amelanchier basalticola', 'Pyrus canadensis', 'Amelanchier confusa', 'Amelanchier huroensis', 'Amelanchier arborea subsp. laevis', 'Amelanchier oblongifolia', 'Amelanchier ovalis var. integrifolia', 'Amelanchier weigandii', 'Amelanchier x grandiflora', 'Wurfbainia aromatica', 'Wurfbainia blumeana', 'Etlingera polycarpa', 'Amorphophallus glabra', 'Ampelocissus bombycina', 'Ampelocissus edulis', 'Ampelocissus gardineri', 'Ampelocissus gracilipes', 'Ampelocissus leonensis', 'Ampelocissus multistriata', 'Ampelocissus schimperiana', 'Amphicarpaea bracteata subsp. edgeworthii', 'Amsinckia tesselata', 'Amyema fitzgeraldii', 'Amyema gibberula', 'Amyema linophylla', 'Amyema lucasii', 'Amyema miraculosa', 'Amyema pendula', 'Amyema thalassia', 'Anadendrum montanum', 'Ananas bracteatus', 'Anchomanes difformis var. pallidus', 'Anchusa sp.', 'Ancylobothrys amoena', 'Ancylobothrys pyriformis', 'Ancylobothrys scandens', ...

# %%
NCBITaxa()
